# %%
# !pip install vaderSentiment
# Out:
# ...
#      -------------------------------------- 126.0/126.0 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# !pip install textblob
# Out:
# ...
#      -------------------------------------- 626.3/626.3 kB 3.6 MB/s eta 0:00:00
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import warnings
warnings.filterwarnings('ignore')
from textblob import TextBlob

# %%
df1=pd.read_csv('Combined_News_DJIA.csv')

# %%
#df1.head()
df1.shape
# Out:
# (1989, 27)

# %%
df2=pd.read_csv('Dow Jones Industrial Average Historical Data.csv')

# %%
#df2.head()
df2.shape
# Out:
# (1989, 7)

# %%
df3 = pd.DataFrame(columns=df2.columns, index=range(0, 1989))
for i in range(0,1989):
    df3.iloc[i]=df2.iloc[1988-i]

# %%
data1=pd.concat([df1,df3],axis=1)
data=data1.copy()

# %%
columns=['Price','Open','High','Low']
for col in columns:
    data[col]=data[col].str.replace(',','')
    data[col]=data[col].astype(float)
data['Vol.']=data['Vol.'].str.replace('M','').astype(float)
data['Vol.']=data['Vol.']*1000000
data.drop('Label',axis=1,inplace=True)

# %%
plt.plot(data['Price'])
plt.title('Time Series plot of DJIA from 2008-08-08 to 2016-07-01')
plt.xlabel('Time')
plt.ylabel('Price')
plt.show()

# %%
data.head()
# Out:
#          Date                                               Top1  \
# 0  2008-08-08  b"Georgia 'downs two Russian warplanes' as cou...
# 1  2008-08-11  b'Why wont America and Nato help us? If they w...
# 2  2008-08-12  b'Remember that adorable 9-year-old who sang a...
# 3  2008-08-13  b' U.S. refuses Israel weapons to attack Iran:...
# 4  2008-08-14  b'All the experts admit that we should legalis...
#
#                                                 Top2  \
# 0            b'BREAKING: Musharraf to be impeached.'
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
# 4  b'War in South Osetia - 89 pictures made by a ...
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# 2  b'"If we had no sexual harassment we would hav...
# ...

# %%
news_col=['Top{}'.format(i) for i in range(1,26)]

# %%
news_col
# Out:
# ['Top1',
#  'Top2',
#  'Top3',
#  'Top4',
#  'Top5',
#  'Top6',
#  'Top7',
#  'Top8',
#  'Top9',
#  'Top10',
#  'Top11',
#  'Top12',
#  'Top13',
#  'Top14',
#  'Top15',
#  'Top16',
#  'Top17',
#  'Top18',
#  'Top19',
#  'Top20',
#  'Top21',
#  'Top22',
#  'Top23',
#  'Top24',
#  'Top25']

# %%
data[news_col]
# Out:
#                                                    Top1  \
# 0     b"Georgia 'downs two Russian warplanes' as cou...
# 1     b'Why wont America and Nato help us? If they w...
# 2     b'Remember that adorable 9-year-old who sang a...
# 3     b' U.S. refuses Israel weapons to attack Iran:...
# 4     b'All the experts admit that we should legalis...
# ...                                                 ...
# 1984  Barclays and RBS shares suspended from trading...
# 1985  2,500 Scientists To Australia: If You Want To ...
# 1986                   Explosion At Airport In Istanbul
# 1987  Jamaica proposes marijuana dispensers for tour...
# 1988  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# 0               b'BREAKING: Musharraf to be impeached.'
# 1           b'Bush puts foot down on Georgian conflict'
# 2                    b"Russia 'ends Georgia operation'"
# 3     b"When the president ordered to attack Tskhinv...
# ...

# %%
data[news_col] = data[news_col].fillna('').astype(str)

# %%
data['combined_news'] = data[news_col].agg(' '.join, axis=1)
data.drop(news_col,axis=1,inplace=True)

# %%
data.drop("Date",axis=1,inplace=True)

# %%
data_new=data.copy()

# %%
data_new
# Out:
#          Price      Open      High       Low         Vol. Change %  \
# 0     11734.32  11432.09  11759.96  11388.04  212830000.0    2.65%
# 1     11782.35  11729.67  11867.11  11675.53  183190000.0    0.41%
# 2     11642.47  11781.70  11782.35  11601.52  173590000.0   -1.19%
# 3     11532.96  11632.81  11633.78  11453.34  182550000.0   -0.94%
# 4     11615.93  11532.07  11718.28  11450.89  159790000.0    0.72%
# ...        ...       ...       ...       ...          ...      ...
# 1984  17140.24  17355.21  17355.21  17063.08  138740000.0   -1.50%
# 1985  17409.72  17190.51  17409.72  17190.51  112190000.0    1.57%
# 1986  17694.68  17456.02  17704.51  17456.02  106380000.0    1.64%
# 1987  17929.99  17712.76  17930.61  17711.80  133030000.0    1.33%
# 1988  17949.37  17924.24  18002.38  17916.91   82160000.0    0.11%
#
#                                           combined_news
# 0     b"Georgia 'downs two Russian warplanes' as cou...
# ...

# %%
for i in range(0,1989):
    data_new['combined_news'][i] =re.sub('[^a-zA-Z0-9 \n\.]', ' ', data_new['combined_news'][i]).replace('b','')

# %%
data_new
# Out:
#          Price      Open      High       Low         Vol. Change %  \
# 0     11734.32  11432.09  11759.96  11388.04  212830000.0    2.65%
# 1     11782.35  11729.67  11867.11  11675.53  183190000.0    0.41%
# 2     11642.47  11781.70  11782.35  11601.52  173590000.0   -1.19%
# 3     11532.96  11632.81  11633.78  11453.34  182550000.0   -0.94%
# 4     11615.93  11532.07  11718.28  11450.89  159790000.0    0.72%
# ...        ...       ...       ...       ...          ...      ...
# 1984  17140.24  17355.21  17355.21  17063.08  138740000.0   -1.50%
# 1985  17409.72  17190.51  17409.72  17190.51  112190000.0    1.57%
# 1986  17694.68  17456.02  17704.51  17456.02  106380000.0    1.64%
# 1987  17929.99  17712.76  17930.61  17711.80  133030000.0    1.33%
# 1988  17949.37  17924.24  18002.38  17916.91   82160000.0    0.11%
#
#                                           combined_news
# 0      Georgia  downs two Russian warplanes  as coun...
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sid_obj= SentimentIntensityAnalyzer()

# %%
neg=[]
neu=[]
pos=[]
compound=[]

for i in range(0,1989):
    sentiment_scores = sid_obj.polarity_scores(data_new['combined_news'][i])
    neg.append(sentiment_scores['neg'])
    neu.append(sentiment_scores['neu'])
    pos.append(sentiment_scores['pos'])
    compound.append(sentiment_scores['compound'])

# %%
data_new['negative']=neg
data_new['neutral']=neu
data_new['positive']=pos
data_new['compound']=compound

# %%
data_new
# Out:
#          Price      Open      High       Low         Vol. Change %  \
# 0     11734.32  11432.09  11759.96  11388.04  212830000.0    2.65%
# 1     11782.35  11729.67  11867.11  11675.53  183190000.0    0.41%
# 2     11642.47  11781.70  11782.35  11601.52  173590000.0   -1.19%
# 3     11532.96  11632.81  11633.78  11453.34  182550000.0   -0.94%
# 4     11615.93  11532.07  11718.28  11450.89  159790000.0    0.72%
# ...        ...       ...       ...       ...          ...      ...
# 1984  17140.24  17355.21  17355.21  17063.08  138740000.0   -1.50%
# 1985  17409.72  17190.51  17409.72  17190.51  112190000.0    1.57%
# 1986  17694.68  17456.02  17704.51  17456.02  106380000.0    1.64%
# 1987  17929.99  17712.76  17930.61  17711.80  133030000.0    1.33%
# 1988  17949.37  17924.24  18002.38  17916.91   82160000.0    0.11%
#
#                                           combined_news  negative  neutral  \
# 0      Georgia  downs two Russian warplanes  as coun...     0.214    0.752
# ...

# %%
data_with_vader=data_new.drop('combined_news',axis=1)

# %%
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity, analysis.sentiment.subjectivity

# Initialize columns for sentiment scores
data_new['sentiment_polarity'] = 0.0
data_new['sentiment_subjectivity'] = 0.0

# Apply sentiment analysis to each row
for i in range(len(data)):
    polarity, subjectivity = get_sentiment(data_new['combined_news'][i])
    data_new.at[i, 'sentiment_polarity'] = polarity
    data_new.at[i, 'sentiment_subjectivity'] = subjectivity

# %%
data_new
# Out:
#          Price      Open      High       Low         Vol. Change %  \
# 0     11734.32  11432.09  11759.96  11388.04  212830000.0    2.65%
# 1     11782.35  11729.67  11867.11  11675.53  183190000.0    0.41%
# 2     11642.47  11781.70  11782.35  11601.52  173590000.0   -1.19%
# 3     11532.96  11632.81  11633.78  11453.34  182550000.0   -0.94%
# 4     11615.93  11532.07  11718.28  11450.89  159790000.0    0.72%
# ...        ...       ...       ...       ...          ...      ...
# 1984  17140.24  17355.21  17355.21  17063.08  138740000.0   -1.50%
# 1985  17409.72  17190.51  17409.72  17190.51  112190000.0    1.57%
# 1986  17694.68  17456.02  17704.51  17456.02  106380000.0    1.64%
# 1987  17929.99  17712.76  17930.61  17711.80  133030000.0    1.33%
# 1988  17949.37  17924.24  18002.38  17916.91   82160000.0    0.11%
#
#                                           combined_news  negative  neutral  \
# 0      Georgia  downs two Russian warplanes  as coun...     0.214    0.752
# ...

# %%
data_new.to_csv('data_with_vader.csv')
